# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Squares.txt", sep=' ')
xValue = df.iloc[:,0]
yValue = df.iloc[:,1]
plt.plot(xValue, yValue)
plt.plot(xValue, yValue, 'ro')
plt.xlabel("Values")
plt.ylabel("Square Values")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
